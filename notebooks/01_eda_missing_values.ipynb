# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('../data/raw/Dataset.csv')

# %%
df['Patient_ID'].unique().shape
# Out:
# (14058,)

# %%
df1=df.copy()

# %%
df1=df1.groupby('Patient_ID')

# %%
df1.head()
# Out:
#         Unnamed: 0  Hour     HR  O2Sat   Temp    SBP   MAP   DBP  Resp  EtCO2  \
# 0                0     0    NaN    NaN    NaN    NaN   NaN   NaN   NaN    NaN
# 1                1     1   65.0  100.0    NaN    NaN  72.0   NaN  16.5    NaN
# 2                2     2   78.0  100.0    NaN    NaN  42.5   NaN   NaN    NaN
# 3                3     3   73.0  100.0    NaN    NaN   NaN   NaN  17.0    NaN
# 4                4     4   70.0  100.0    NaN  129.0  74.0  69.0  14.0    NaN
# ...            ...   ...    ...    ...    ...    ...   ...   ...   ...    ...
# 546095           0     0  106.0   97.0    NaN    NaN  77.0   NaN  23.0    NaN
# 546096           1     1  103.0   99.0  36.78    NaN  81.0   NaN  20.0    NaN
# 546097           2     2  108.0   97.0    NaN    NaN  88.0   NaN  24.0    NaN
# 546098           3     3  102.0   97.0    NaN    NaN  46.0   NaN  24.0    NaN
# 546099           4     4  102.0   97.0    NaN    NaN  62.0   NaN  26.0    NaN
#
# ...

# %%
df = df.set_index(['Patient_ID','ICULOS'])

# %%
df.head()
# Out:
#                    Unnamed: 0  Hour    HR  O2Sat  Temp    SBP   MAP   DBP  \
# Patient_ID ICULOS
# 17072.0    1.0              0     0   NaN    NaN   NaN    NaN   NaN   NaN
#            2.0              1     1  65.0  100.0   NaN    NaN  72.0   NaN
#            3.0              2     2  78.0  100.0   NaN    NaN  42.5   NaN
#            4.0              3     3  73.0  100.0   NaN    NaN   NaN   NaN
#            5.0              4     4  70.0  100.0   NaN  129.0  74.0  69.0
#
#                    Resp  EtCO2  ...   PTT   WBC  Fibrinogen  Platelets    Age  \
# Patient_ID ICULOS               ...
# 17072.0    1.0      NaN    NaN  ...   NaN   NaN         NaN        NaN  68.54
#            2.0     16.5    NaN  ...   NaN   NaN         NaN        NaN  68.54
#            3.0      NaN    NaN  ...   NaN   NaN         NaN        NaN  68.54
#            4.0     17.0    NaN  ...   NaN   NaN         NaN        NaN  68.54
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Hour', 'HR', 'O2Sat', 'Temp', 'SBP', 'MAP', 'DBP',
#        'Resp', 'EtCO2', 'BaseExcess', 'HCO3', 'FiO2', 'pH', 'PaCO2', 'SaO2',
#        'AST', 'BUN', 'Alkalinephos', 'Calcium', 'Chloride', 'Creatinine',
#        'Bilirubin_direct', 'Glucose', 'Lactate', 'Magnesium', 'Phosphate',
#        'Potassium', 'Bilirubin_total', 'TroponinI', 'Hct', 'Hgb', 'PTT', 'WBC',
#        'Fibrinogen', 'Platelets', 'Age', 'Gender', 'Unit1', 'Unit2',
#        'HospAdmTime', 'SepsisLabel'],
#       dtype='str')

# %%
un_wanted_column=['Unit1', 'Unit2', 'HospAdmTime', 'Unnamed: 0']
df=df.drop(columns=un_wanted_column)

# %%
df.head(20)
# Out:
#                    Hour    HR  O2Sat   Temp    SBP   MAP   DBP  Resp  EtCO2  \
# Patient_ID ICULOS
# 17072.0    1.0        0   NaN    NaN    NaN    NaN   NaN   NaN   NaN    NaN
#            2.0        1  65.0  100.0    NaN    NaN  72.0   NaN  16.5    NaN
#            3.0        2  78.0  100.0    NaN    NaN  42.5   NaN   NaN    NaN
#            4.0        3  73.0  100.0    NaN    NaN   NaN   NaN  17.0    NaN
#            5.0        4  70.0  100.0    NaN  129.0  74.0  69.0  14.0    NaN
#            6.0        5  62.0  100.0    NaN  124.0  85.0  61.0  14.0    NaN
#            7.0        6  61.0  100.0    NaN  101.0  75.0  58.0  14.0    NaN
#            8.0        7  68.0  100.0  35.78  142.0  93.5  78.0  16.0    NaN
#            9.0        8  71.0  100.0    NaN  121.0  74.0  91.0  14.0    NaN
#            10.0       9  69.0  100.0    NaN  120.0  79.0  98.0  14.0    NaN
#            11.0      10  75.0  100.0    NaN  146.0  93.0  67.0  14.0    NaN
# ...

# %%
df['Spesis_onset']=df.groupby('Patient_ID')['SepsisLabel'].diff()

# %%
df.head()
# Out:
#                    Hour    HR  O2Sat  Temp    SBP   MAP   DBP  Resp  EtCO2  \
# Patient_ID ICULOS
# 17072.0    1.0        0   NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN
#            2.0        1  65.0  100.0   NaN    NaN  72.0   NaN  16.5    NaN
#            3.0        2  78.0  100.0   NaN    NaN  42.5   NaN   NaN    NaN
#            4.0        3  73.0  100.0   NaN    NaN   NaN   NaN  17.0    NaN
#            5.0        4  70.0  100.0   NaN  129.0  74.0  69.0  14.0    NaN
#
#                    BaseExcess  ...   Hct  Hgb   PTT   WBC  Fibrinogen  \
# Patient_ID ICULOS              ...
# 17072.0    1.0            NaN  ...   NaN  NaN   NaN   NaN         NaN
#            2.0            NaN  ...   NaN  NaN   NaN   NaN         NaN
#            3.0            NaN  ...   NaN  NaN   NaN   NaN         NaN
#            4.0            NaN  ...   NaN  NaN   NaN   NaN         NaN
#            5.0            NaN  ...  29.7  9.5  30.6  11.3         NaN
#
# ...

# %%
df[df['SepsisLabel']==1].head(20)
# Out:
#                    Hour     HR  O2Sat   Temp    SBP   MAP   DBP  Resp  EtCO2  \
# Patient_ID ICULOS
# 11093.0    53.0      50   87.0  100.0    NaN  105.0  65.0  67.0  19.0    NaN
#            54.0      51   93.0  100.0    NaN   94.0  72.0  56.0  18.0    NaN
#            55.0      52   95.0  100.0    NaN  110.0  80.0  90.0  13.0    NaN
#            56.0      53   94.0  100.0    NaN   95.0  74.0  58.0  20.0    NaN
#            57.0      54   94.0  100.0    NaN   95.0  73.0  58.0  22.0    NaN
#            58.0      55   97.0  100.0    NaN   96.0  75.0  60.0  13.0    NaN
#            59.0      56   99.0  100.0    NaN  102.0  79.0  63.0  15.0    NaN
#            60.0      57   94.0  100.0    NaN   84.0  62.0  53.0  17.0    NaN
#            61.0      58   97.0  100.0    NaN   87.0  79.0  69.0  23.0    NaN
#            62.0      59   96.0  100.0    NaN   76.0  65.0  55.0  16.0    NaN
# 10355.0    67.0      66   97.0   95.0  36.50  101.0  66.0  50.0  31.5    NaN
# ...

# %%
df.head(40)['Hour']
# Out:
# Patient_ID  ICULOS
# 17072.0     1.0        0
#             2.0        1
#             3.0        2
#             4.0        3
#             5.0        4
#             6.0        5
#             7.0        6
#             8.0        7
#             9.0        8
#             10.0       9
#             11.0      10
#             12.0      11
#             13.0      12
#             14.0      13
#             15.0      14
#             16.0      15
#             17.0      16
#             18.0      17
#             19.0      18
#             20.0      19
#             21.0      20
#             22.0      21
#             23.0      22
#             24.0      23
#             25.0      24
#             26.0      25
#             27.0      26
#             28.0      27
#             29.0      28
#             30.0      29
#             31.0      30
#             32.0      31
#             33.0      32
#             34.0      33
#             35.0      34
#             36.0      35
# ...

# %%
# بنعمل ميزة جديدة اسمها 'True_Hour' عشان نعرف الساعة كام في اليوم بالظبط
df['True_Hour'] = df['Hour'] % 24

# %%
df['True_Hour'].head(40)
# Out:
# Patient_ID  ICULOS
# 17072.0     1.0        0
#             2.0        1
#             3.0        2
#             4.0        3
#             5.0        4
#             6.0        5
#             7.0        6
#             8.0        7
#             9.0        8
#             10.0       9
#             11.0      10
#             12.0      11
#             13.0      12
#             14.0      13
#             15.0      14
#             16.0      15
#             17.0      16
#             18.0      17
#             19.0      18
#             20.0      19
#             21.0      20
#             22.0      21
#             23.0      22
#             24.0      23
#             25.0       0
#             26.0       1
#             27.0       2
#             28.0       3
#             29.0       4
#             30.0       5
#             31.0       6
#             32.0       7
#             33.0       8
#             34.0       9
#             35.0      10
#             36.0      11
# ...
